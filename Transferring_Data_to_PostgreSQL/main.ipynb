# %%
import pandas as pd
import psycopg2
import sys
sys.path.append('..')
sys.path.append(r"original_process/")

from step3_creating_empty_tables_of_redcap_data import creating_empty_redcap_data_tables
from step5_creating_empty_tables_old_data import creating_empty_old_data_tables
from step8_add_column_names_mapping_between_datasets import add_column_names_mapping
from step6_uploading_redcap_data import upload_redcap_data  
from step_7_uploading_old_data import upload_old_data
conn_str = "dbname=postgres user=postgres password=asdf123"

# %% [markdown]
# ### Start with creating the primary keys for the original datasets

# %% [markdown]
# ## Step 1 - create sql database

# %%
f = open("create sql database - step 1", "r")
prompt = f.read()

conn = psycopg2.connect(conn_str)
cur = conn.cursor()
cur.execute(prompt)
conn.commit()
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# DuplicateSchema                           Traceback (most recent call last)
# Cell In[3], line 6
#       4 conn = psycopg2.connect(conn_str)
#       5 cur = conn.cursor()
# ----> 6 cur.execute(prompt)
#       7 conn.commit()
#       8 cur.close()
#
# DuplicateSchema: schema "auxiliary_questionnaires_data" already exists

# %% [markdown]
# ## Step 2 - create auxiliary_questionnaires_data & Redcap data columns

# %%
f = open("create sql database - step 2 auxiliary_questionnaires_data", "r")
prompt = f.read()

conn = psycopg2.connect(conn_str)
cur = conn.cursor()
cur.execute(prompt)
conn.commit()
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[4], line 6
#       4 conn = psycopg2.connect(conn_str)
#       5 cur = conn.cursor()
# ----> 6 cur.execute(prompt)
#       7 conn.commit()
#       8 cur.close()
#
# DuplicateTable: relation "redcap_data_questionnaires_columns_names" already exists

# %% [markdown]
# ## Step 3 - create empty redcap tables

# %%
creating_empty_redcap_data_tables(conn_str)
# Out:
# C:\Users\nogur\Documents\DeppClinic\Transferring_Data_to_PostgreSQL\step3_creating_empty_tables_of_redcap_data.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 creating_empty_redcap_data_tables(conn_str)
#
# File ~\Documents\DeppClinic\Transferring_Data_to_PostgreSQL\step3_creating_empty_tables_of_redcap_data.py:22, in creating_empty_redcap_data_tables(conn_str)
#      20 conn = psycopg2.connect(conn_str)
#      21 cur = conn.cursor()
# ---> 22 cur.execute(create_table)
#      23 conn.commit()
#      24 cur.close()
#
# DuplicateTable: relation "c_ssrs_intake" already exists

# %% [markdown]
# ## Step 4 - create auxiliary_questionnaires_data - Old data columns

# %%
f = open("create sql database - step 4 old data", "r")
prompt = f.read()

conn = psycopg2.connect(conn_str)
cur = conn.cursor()
cur.execute(prompt)
conn.commit()
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[6], line 6
#       4 conn = psycopg2.connect(conn_str)
#       5 cur = conn.cursor()
# ----> 6 cur.execute(prompt)
#       7 conn.commit()
#       8 cur.close()
#
# DuplicateTable: relation "old_data_questionnaires_columns_names" already exists

# %% [markdown]
# ## Step 5 - create empty old data tables

# %%
creating_empty_old_data_tables(conn_str)
# Out:
# C:\Users\nogur\Documents\DeppClinic\Transferring_Data_to_PostgreSQL\step5_creating_empty_tables_old_data.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 creating_empty_old_data_tables(conn_str)
#
# File ~\Documents\DeppClinic\Transferring_Data_to_PostgreSQL\step5_creating_empty_tables_old_data.py:31, in creating_empty_old_data_tables(conn_str)
#      29 conn = psycopg2.connect(conn_str)
#      30 cur = conn.cursor()
# ---> 31 cur.execute(create_table)
#      32 conn.commit()
#      33 cur.close()
#
# DuplicateTable: relation "c_ssrs_intake" already exists

# %% [markdown]
# ## Step 6 - upload redcap data

# %%
upload_redcap_data(conn_str)
# Out:
# C:\Users\nogur\Documents\DeppClinic\Transferring_Data_to_PostgreSQL\step6_uploading_redcap_data.py:66: DtypeWarning: Columns (44,46,51,53,99,145,325,366,459,464,466,501,507,512,514,516,519,521,530,532,569,571,580,599,766,771,773,779,784,789,794,798,800,804,809,811,813,816,818,827,829,849,866,868,877,896,906,941,964,1002,1014,1025,1063,1068,1070,1076,1081,1086,1091,1093,1095,1097,1099,1100,1126,1142,1149,1165,1168,1172,1173,1177,1178,1179,1180,1182,1183,1184,1187,1188,1190,1207,1212,1229,1232,1260,1262,1264,1266,1268,1270,1271,1281,1283,1285,1287,1289,1291,1293,1295,1297,1299,1301,1303,1305,1306,1319,1321,1324,1326,1336,1338,1340,1342,1343,1344,1350,1351,1352,1353,1459,1465,1467,1468,1470,1486,1489,1492,1496,1513,1515,1516,1517,1523,1524,1525,1526,1580,1650,1653,1654) have mixed types. Specify dtype option on import or set low_memory=False.
#   redcap_df = pd.read_csv(r"..\Data\Transferring_Data_to_PostgreSQL\redcap_data.csv")
# ...

# %% [markdown]
# ## Step 7 - upload old data

# %%
upload_old_data(conn_str)
# Out:
# C:\Users\nogur\Documents\DeppClinic\Transferring_Data_to_PostgreSQL\step_7_uploading_old_data.py:64: DtypeWarning: Columns (1593) have mixed types. Specify dtype option on import or set low_memory=False.
#   old_data_df = pd.read_csv(r"..\Data\Transferring_Data_to_PostgreSQL\old_data.csv")
# C:\Users\nogur\Documents\DeppClinic\Transferring_Data_to_PostgreSQL\step_7_uploading_old_data.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   questionnaire_columns = list(pd.read_sql_query(sql, conn).table_name)
# C:\Users\nogur\Documents\DeppClinic\Transferring_Data_to_PostgreSQL\step_7_uploading_old_data.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %% [markdown]
# ## step 8- add column names mapping between datasets

# %%
add_column_names_mapping(conn_str)
# Out:
# C:\Users\nogur\Documents\DeppClinic\Transferring_Data_to_PostgreSQL\..\creating_the_clinic_dataset\step1_fill_missing_2021_clin_stu\completing_missing_clinician_questionnaire_2021.py:151: DtypeWarning: Columns (48) have mixed types. Specify dtype option on import or set low_memory=False.
#   old_data = pd.read_csv(r"C:/Users/nogur/Documents/DeppClinic/Data/OriginalDataset/Schneider Depression Clinic Database.csv", na_values=' ')
# ...
