# %%
import sys
sys.path.append(r"../../../")

import pandas as pd
from cross_val import main

# %%
main()
# Out:
# patient_id = 'Y10029'
# action = 0
# action = 0
# action = 0
# patient_id = 'A3880'
# action = 0
# action = 0
# action = 0
# patient_id = 'L9319'
# action = 0
# action = 0
# action = 0
# patient_id = 'Y3705'
# action = 0
# action = 0
# action = 0
# patient_id = 'H9120'
# action = 0
# action = 0
# action = 0
# patient_id = 'N0810'
# action = 0
# action = 0
# action = 0
# patient_id = 'A0120'
# action = 0
# action = 0
# action = 0
# patient_id = 'O8217'
# action = 0
# action = 0
# action = 0
# patient_id = 'G0327'
# action = 0
# action = 0
# action = 0
# patient_id = 'S1313'
# action = 0
# action = 0
# action = 0
# patient_id = 'L5678'
# action = 0
# action = 0
# action = 0
# patient_id = 'L6143'
# action = 0
# action = 0
# action = 0
# patient_id = 'G8120'
# action = 0
# action = 0
# action = 0
# patient_id = 'H9132'
# action = 0
# action = 0
# action = 0
# patient_id = 'T0305'
# action = 0
# action = 0
# action = 0
# patient_id = 'A1066'
# action = 0
# action = 0
# action = 0
# ...
