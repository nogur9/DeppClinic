# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\nogur\anaconda3\envs\DeppClinic\lib\site-packages\numpy\__init__.py:143: UserWarning: mkl-service package failed to import, therefore Intel(R) MKL initialization ensuring its correct out-of-the box operation under condition when Gnu OpenMP had already been loaded by Python process is not assured. Please install mkl-service package, see http://github.com/IntelPython/mkl-service
#   from . import _distributor_init
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16992\1492400551.py in <module>
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#
# ~\anaconda3\envs\DeppClinic\lib\site-packages\pandas\__init__.py in <module>
#      14
#      15 if missing_dependencies:
# ---> 16     raise ImportError(
#      17         "Unable to import required dependencies:\n" + "\n".join(missing_dependencies)
#      18     )
#
# ...

# %%
df = pd.read_csv("DeppClinic_prediction_task.csv")

# %%
SAS = [
    'sas_1',
    'sas_2',
    'sas_3',
    'sas_4',
    'sas_5',
    'sas_6',
    'sas_7',
    'sas_8',
    'sas_9',
    'sas_10',
    'sas_11',
    'sas_12',
    'sas_13',
    'sas_14',
    'sas_15',
    'sas_16',
    'sas_17',
    'sas_18',
    'sas_19',
    'sas_20',
    'sas_21',
    'sas_22',
    'sas_23'
]

# %%
df[SAS]
# Out:
#      sas_1  sas_2  sas_3  sas_4  sas_5  sas_6  sas_7  sas_8  sas_9  sas_10  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 1      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 732    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 733    1.0    2.0    3.0    1.0    2.0    3.0    3.0    2.0    3.0     2.0
# 734    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 735    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 736    2.0    4.0    5.0    4.0    4.0    5.0    3.0    4.0    5.0     4.0
#
# ...
