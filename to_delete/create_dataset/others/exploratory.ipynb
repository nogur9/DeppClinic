# %%
import sys
sys.path.append(r"../../utils")
import numpy as np 
import pandas as pd
from questions_columns import sci_af_ca, c_ssrs, sci_mother, sci_father, scs_clin, siq, sdq,c_ssrs_intake, mfq, scared, ATHENS, SAS, c_ssrs_clin, demographics_m, target_variables, imputation_questionnaires, all_target_columns
from utils import simple_eda, impute_from_column
from questionnaires_aggregation import c_ssrs_aggregation, c_ssrs_intake_aggregation, sci_af_ac_aggregation
import missingno as msno

# %%
df = pd.read_csv(r'data_for_CFA2.csv', na_values = ' ')

# %%
eda = False
if eda:
    simple_eda(df, columns = list(df.columns), title = 'CFA', display_additional_columns=False)

# %%
msno.matrix(df[sci_af_ca])
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df[scs_clin])
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df[sci_father])
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df[sci_mother])
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>
